# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
from dash.dependencies import Input, Output
from xgboost import XGBClassifier
import pickle
import radar_plotting

# %%
app = dash.Dash()
server = app.server

# %%
kmeans_df = pd.read_csv('results/kmeans_results.csv')
ss_df = pd.read_csv('results/ss_results.csv')

# %%
kmeans_model = pickle.load(open("models/kmeans_model.pkl", "rb"))
ss_model = XGBClassifier()
ss_model.load_model('models/final_model.model')

# %%
input_types_stats = ['MIN', 'PTS', 'FGA', 'FG%', '3PA', '3P%', 'REB', 'AST',
       'TO', 'STL', 'BLK', 'Close FGA', 'Close FG%', 'Mid FGA', 'Mid FG%',
       'Post_Ups', 'Drives', 'CS_3PA', 'CS_3P%', 'PP100Pos', 'AST %', 'REB %',
       'USG %', 'Height', 'Pos']

# %%
app.layout = html.Div([
    html.Div([
        dcc.Graph(id='our_graph')
    ], className='seven columns'),
    
    # DROPDOWN
    html.Div([
        html.Br(),
        html.Div(id='output_data'),
        html.Br(),
        
        html.Label(['Choose Year'], style={'font-weight': 'bold', "text-align": 'center'}),
        
        dcc.Dropdown(id='my_dropdown',
                    options=[
                        {'label': '2015-16', 'value': 2015},
                        {'label': '2016-17', 'value': 2016},
                        {'label': '2017-18', 'value': 2017},
                        {'label': '2018-19', 'value': 2018},
                        {'label': '2019-20', 'value': 2019},
                        {'label': '2020-21', 'value': 2020},
                        {'label': 'All', 'value': 0}
                    ],
                     optionHeight=35, #visual space between options
                     value='All', #default dropdown value
                     disabled=False, #disables whole dropdown
                     multi=False, # allows multiple dropdown selections
                     placeholder='Please select year...', #gray default text         
        ),  
    ], className='three columns'),
    
    # CHECKLIST
    html.Div([
        html.Br(),
        html.Div(id='output_data'),
        html.Br(),
        
        html.Label(['Select Team Type'], style={'font-weight': 'bold', "text-align": 'center'}),
        
        dcc.Checklist(
            id='my_checklist',
            options=[
                {'label': x, 'value': True, 'disabled':False}
                for x in ['Good', 'Bad', 'Average']
            ],
            value=[False,False,False],
            
            className='my_box_container',
            
            inputClassName='my_box_input',
            
            labelClassName='my_box_label',
            
        ),
    ])
    
])

#---------------------------------------------------------------------
# Connecting Dropdown & Checklist values to graph
@app.callback(
    Output(component_id='our_graph', component_property='figure'),
    [Input(component_id='my_dropdown', component_property='value')],
    [Input(component_id='my_checklist', component_property='value')]
)

def update_graph(my_dropdown, my_checklist):

# %%
app.run_server(host='0.0.0.0', debug=False)
# Out:
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
# Dash is running on http://0.0.0.0:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8050/ (Press CTRL+C to quit)
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# 127.0.0.1 - - [15/May/2021 19:46:04] "GET / HTTP/1.1" 500 -
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# 127.0.0.1 - - [15/May/2021 19:46:04] "GET /favicon.ico HTTP/1.1" 500 -
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on / [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# 127.0.0.1 - - [15/May/2021 19:46:08] "GET / HTTP/1.1" 500 -
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1945, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/flask/app.py", line 1993, in try_trigger_before_first_request_functions
#     func()
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/dash.py", line 1096, in _setup_server
#     _validate.validate_layout(self.layout, self._layout_value())
#   File "/Users/hoganbyun/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/dash/_validate.py", line 373, in validate_layout
#     raise exceptions.DuplicateIdError(
# dash.exceptions.DuplicateIdError: Duplicate component id found in the initial layout: `output_data`
# 127.0.0.1 - - [15/May/2021 19:46:08] "GET /favicon.ico HTTP/1.1" 500 -

# %%
#app.layout = html.Div([
    # Setting main title of the dashboard
#    html.H1("NBA Player Classification", style={"textAlign":"center"}) , html.Div([
 #       html.H1("Player Classifier 1", style={"textAling":"center"}), dcc.Input(
  #          id='my_{}'.format(x),
   #         type=x,
    #        placeholder="Enter {}".format(x),
     #       debounce=True,
      #      disabled=False,
       #     readOnly=False,
        #    required=False,
            
       # )
        
   # ])
#])
